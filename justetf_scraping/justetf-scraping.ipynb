# %% [markdown]
# # Scraping the justETF [Screener](https://www.justetf.com/en/find-etf.html)

# %% [markdown]
# ## Content
#
# - [Request the data](#request)
# - [Clean up the data](#cleanup)
# - [Enrich the data](#enrich)
# - [Save the data](#save)
# - [Visualize some statistics](#visualize)
# - [Search over the data](#search)

# %%
# %load_ext nb_black
# %load_ext autoreload

# %%
# %autoreload 1
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %aimport utils

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# <a id="request"></a>
# ## Request the data

# %%
last_four_years = [
    str((pd.Timestamp("now") - pd.DateOffset(years=i)).year) for i in range(1, 5)
]

# %%
DETAILS_KEY_MAPPING = {
    # IDs
    "isin": "isin",
    "wkn": "wkn",
    "ticker": "ticker",
    "valorNumber": "valor",
    # Basic info
    "name": "name",
    "groupValue": "index",
    "inceptionDate": "date",
    "strategy": "strategy",  # Custom field added during request
    "domicileCountry": "domicile_country",
    "fundCurrency": "currency",
    "hasSecuritiesLending": "securities_lending",
    "distributionPolicy": "dividends",
    "ter": "ter",
    "replicationMethod": "replication",
    "fundSize": "size",
    # Value return
    "ytdReturnCUR": "yesterday",
    "weekReturnCUR": "last_week",
    "monthReturnCUR": "last_month",
    "threeMonthReturnCUR": "last_three_months",
    "sixMonthReturnCUR": "last_six_months",
    "yearReturnCUR": "last_year",
    "threeYearReturnCUR": "last_three_years",
    "fiveYearReturnCUR": "last_five_years",
    "yearReturn1CUR": last_four_years[0],
    "yearReturn2CUR": last_four_years[1],
    "yearReturn3CUR": last_four_years[2],
    "yearReturn4CUR": last_four_years[3],
    # Dividends
    "currentDividendYield": "last_dividends",
    "yearDividendYield": "last_year_dividends",
    # Volatility
    "yearVolatilityCUR": "last_year_volatility",
    "threeYearVolatilityCUR": "last_three_years_volatility",
    "fiveYearVolatilityCUR": "last_five_years_volatility",
    # Return/Risk
    "yearReturnPerRiskCUR": "last_year_return_per_risk",
    "threeYearReturnPerRiskCUR": "last_three_years_return_per_risk",
    "fiveYearReturnPerRiskCUR": "last_five_years_return_per_risk",
    # Ignored fields
    # "groupParam": query for index search, indices are already received
    # "selected": not interesting
    # "clazz": some value, the most are empty strings, some are "highl_c"
    # "savingsPlanReady": "Savings plan ready from x.xx EUR" text
}

# %%
INT64_COLUMNS = ["valor", "size"]
CATEGORY_COLUMNS = ["strategy", "domicile_country", "dividends", "replication"]
FLOAT_COLUMNS = [
    "ter",
    "yesterday",
    "last_week",
    "last_month",
    "last_three_months",
    "last_six_months",
    "last_year",
    "last_three_years",
    "last_five_years",
    "last_dividends",
    "last_year_dividends",
    "last_year_volatility",
    "last_three_years_volatility",
    "last_five_years_volatility",
    "last_year_return_per_risk",
    "last_three_years_return_per_risk",
    "last_five_years_return_per_risk",
] + last_four_years

# %%
data = {key: [] for key in DETAILS_KEY_MAPPING}
for sample in utils.make_request():
    for key, values in data.items():
        values.append(sample[key])

# %%
etf_df = pd.DataFrame(data).rename(columns=DETAILS_KEY_MAPPING)

# %%
etf_df.shape
# Out:
# (3349, 35)

# %%
etf_df.head(3)
# Out:
#            isin     wkn ticker      valor  \
# 0  GB00BM9JYH62  A3GZKD   AVMX          -
# 1  IE000GGQK173  A3D4VW    R8T  125589092
# 2  IE00B0M62Y33  A0HGWF   IUSJ    2308837
#
#                                                 name  \
# 0                                  Global X Aave ETP
# 1  abrdn Global Real Estate Active Thematics UCIT...
# 2                              iShares AEX UCITS ETF
#
#                                        index      date   strategy  \
# 0                                       Aave  13.03.23  Long-only
# 1  abrdn Global Real Estate Active Thematics  22.02.23  Long-only
# 2                                       AEX®  18.11.05  Long-only
#
#   domicile_country currency securities_lending     dividends    ter  \
# 0           Jersey      USD                 No  Accumulating  0.99%
# 1          Ireland      USD                 No  Accumulating  0.40%
# 2          Ireland      EUR                Yes  Distributing  0.30%
#
#               replication size yesterday last_week last_month  \
# 0  Physically<br />backed    0    15.36%    11.89%     24.96%
# 1        Full replication   10    -1.82%     1.21%      1.88%
# 2        Full replication  622    12.02%     2.17%      3.09%
#
#   last_three_months last_six_months last_year last_three_years  \
# 0            30.02%         105.83%    70.53%                -
# 1            -1.08%           9.93%     9.54%                -
# 2            12.44%          22.56%    22.89%           34.18%
#
#   last_five_years    2023     2022    2021   2020 last_dividends  \
# 0               -       -        -       -      -              -
# 1               -       -        -       -      -              -
# 2          79.49%  16.77%  -11.78%  29.89%  5.14%          1.90%
#
#   last_year_dividends last_year_volatility last_three_years_volatility  \
# 0                   -               74.74%                           -
# 1                   -               15.23%                           -
# 2               2.28%               11.20%                      16.15%
#
#   last_five_years_volatility last_year_return_per_risk  \
# 0                          -                      0.94
# 1                          -                      0.62
# 2                     18.52%                      2.04
#
#   last_three_years_return_per_risk last_five_years_return_per_risk
# 0                                -                               -
# 1                                -                               -
# 2                             0.64                            0.67

# %%
len(etf_df["isin"].unique())
# Out:
# 3199

# %% [markdown]
# <a id="cleanup"></a>
# ## Clean up the data

# %%
for column in etf_df:
    etf_df[column] = (
        etf_df[column]
        .str.replace("<br />", " ")
        .str.replace(",", "")
        .replace("-", pd.NA)
    )

# %%
for column in INT64_COLUMNS:
    try:
        etf_df[column] = etf_df[column].astype("Int64")
    except BaseException as e:
        print(type(e))
        str_e = str(e)
        print(str_e)
        err_value = str_e[str_e.index("'") + 1 : str_e.rindex("'")]
# Out:
# <class 'ValueError'>
# invalid literal for int() with base 10: 'BPDX196'

# %%
for column in CATEGORY_COLUMNS:
    etf_df[column] = etf_df[column].astype("category")

# %%
for column in FLOAT_COLUMNS:
    etf_df[column] = (
        etf_df[column].str.removesuffix("%").replace(pd.NA, "nan").astype("float64")
    )

# %%
etf_df["date"] = pd.to_datetime(etf_df["date"], format="%d.%m.%y")

# %% [markdown]
# Keep insertion date, but also calculate age in years to simplify search over dataset.

# %%
columns = etf_df.columns.tolist()
etf_df["age"] = (
    pd.Timestamp("now") - pd.to_datetime(etf_df["date"], format="%d.%m.%y")
) / pd.to_timedelta(365, unit="D")
columns.insert(columns.index("date") + 1, "age")
etf_df = etf_df[columns]

# %%
etf_df["securities_lending"] = (
    etf_df["securities_lending"].replace({"Yes": True, "No": False}).astype("bool")
)

# %% [markdown]
# Separate hedged flag from currency.

# %%
columns = etf_df.columns.tolist()
columns.insert(columns.index("currency") + 1, "hedged")
etf_df["hedged"] = etf_df["currency"].str.endswith("Hedged")
etf_df["currency"] = etf_df["currency"].str.removesuffix(" Hedged").astype("category")
etf_df = etf_df[columns]

# %%
etf_df.head(3)
# Out:
#            isin     wkn ticker      valor  \
# 0  GB00BM9JYH62  A3GZKD   AVMX       <NA>
# 1  IE000GGQK173  A3D4VW    R8T  125589092
# 2  IE00B0M62Y33  A0HGWF   IUSJ    2308837
#
#                                                 name  \
# 0                                  Global X Aave ETP
# 1  abrdn Global Real Estate Active Thematics UCIT...
# 2                              iShares AEX UCITS ETF
#
#                                        index       date        age   strategy  \
# 0                                       Aave 2023-03-13   1.042777  Long-only
# 1  abrdn Global Real Estate Active Thematics 2023-02-22   1.094832  Long-only
# 2                                       AEX® 2005-11-18  18.368805  Long-only
#
#   domicile_country currency  hedged  securities_lending     dividends   ter  \
# 0           Jersey      USD   False               False  Accumulating  0.99
# 1          Ireland      USD   False               False  Accumulating  0.40
# 2          Ireland      EUR   False                True  Distributing  0.30
#
#          replication  size  yesterday  last_week  last_month  \
# 0  Physically backed     0      15.36      11.89       24.96
# 1   Full replication    10      -1.82       1.21        1.88
# 2   Full replication   622      12.02       2.17        3.09
#
#    last_three_months  last_six_months  last_year  last_three_years  \
# 0              30.02           105.83      70.53               NaN
# 1              -1.08             9.93       9.54               NaN
# 2              12.44            22.56      22.89             34.18
#
#    last_five_years   2023   2022   2021  2020  last_dividends  \
# 0              NaN    NaN    NaN    NaN   NaN             NaN
# 1              NaN    NaN    NaN    NaN   NaN             NaN
# 2            79.49  16.77 -11.78  29.89  5.14             1.9
#
#    last_year_dividends  last_year_volatility  last_three_years_volatility  \
# 0                  NaN                 74.74                          NaN
# 1                  NaN                 15.23                          NaN
# 2                 2.28                 11.20                        16.15
#
#    last_five_years_volatility  last_year_return_per_risk  \
# 0                         NaN                       0.94
# 1                         NaN                       0.62
# 2                       18.52                       2.04
#
#    last_three_years_return_per_risk  last_five_years_return_per_risk
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                              0.64                             0.67

# %% [markdown]
# <a id="enrich"></a>
# ## Enrich the data

# %%
columns = etf_df.columns.tolist()

# %%
etf_df["asset"] = pd.NA
for asset, name in utils.ASSETS.items():
    isins = {sample["isin"] for sample in utils.make_request(asset=asset)}
    mask = etf_df["isin"].isin(isins)
    etf_df.loc[mask, "asset"] = name
etf_df["asset"] = etf_df["asset"].astype("category")

# %%
etf_df["instrument"] = pd.NA
for instrument, name in utils.INSTRUMENTS.items():
    isins = {sample["isin"] for sample in utils.make_request(instrument=instrument)}
    mask = etf_df["isin"].isin(isins)
    etf_df.loc[mask, "instrument"] = name
etf_df["instrument"] = etf_df["instrument"].astype("category")

# %%
etf_df["region"] = pd.NA
for region, name in utils.REGIONS.items():
    isins = {sample["isin"] for sample in utils.make_request(region=region)}
    mask = etf_df["isin"].isin(isins)
    etf_df.loc[mask, "region"] = name
etf_df["region"] = etf_df["region"].astype("category")

# %%
new_columns = ["asset", "instrument", "region"]
for exchange, name in utils.EXCHANGES.items():
    name = f"at_{name}"
    etf_df[name] = False
    new_columns.append(name)
    isins = {sample["isin"] for sample in utils.make_request(exchange=exchange)}
    mask = etf_df["isin"].isin(isins)
    etf_df.loc[mask, name] = True

# %%
etf_df = etf_df[
    columns[: columns.index("size") + 1]
    + new_columns
    + columns[columns.index("size") + 1 :]
]

# %%
etf_df.shape
# Out:
# (3349, 46)

# %%
etf_df.head(3)
# Out:
#            isin     wkn ticker      valor  \
# 0  GB00BM9JYH62  A3GZKD   AVMX       <NA>
# 1  IE000GGQK173  A3D4VW    R8T  125589092
# 2  IE00B0M62Y33  A0HGWF   IUSJ    2308837
#
#                                                 name  \
# 0                                  Global X Aave ETP
# 1  abrdn Global Real Estate Active Thematics UCIT...
# 2                              iShares AEX UCITS ETF
#
#                                        index       date        age   strategy  \
# 0                                       Aave 2023-03-13   1.042777  Long-only
# 1  abrdn Global Real Estate Active Thematics 2023-02-22   1.094832  Long-only
# 2                                       AEX® 2005-11-18  18.368805  Long-only
#
#   domicile_country currency  hedged  securities_lending     dividends   ter  \
# 0           Jersey      USD   False               False  Accumulating  0.99
# 1          Ireland      USD   False               False  Accumulating  0.40
# 2          Ireland      EUR   False                True  Distributing  0.30
#
#          replication  size             asset instrument region  at_gettex  \
# 0  Physically backed     0  Cryptocurrencies        ETN    NaN       True
# 1   Full replication    10       Real Estate        ETF  World       True
# 2   Full replication   622            Equity        ETF    NaN       True
#
#    at_xetra  at_london  at_euronext  at_stuttgart  at_six  yesterday  \
# 0      True      False        False         False   False      15.36
# 1      True      False        False         False   False      -1.82
# 2     False       True        False         False    True      12.02
#
#    last_week  last_month  last_three_months  last_six_months  last_year  \
# 0      11.89       24.96              30.02           105.83      70.53
# 1       1.21        1.88              -1.08             9.93       9.54
# 2       2.17        3.09              12.44            22.56      22.89
#
#    last_three_years  last_five_years   2023   2022   2021  2020  \
# 0               NaN              NaN    NaN    NaN    NaN   NaN
# 1               NaN              NaN    NaN    NaN    NaN   NaN
# 2             34.18            79.49  16.77 -11.78  29.89  5.14
#
#    last_dividends  last_year_dividends  last_year_volatility  \
# 0             NaN                  NaN                 74.74
# 1             NaN                  NaN                 15.23
# 2             1.9                 2.28                 11.20
#
#    last_three_years_volatility  last_five_years_volatility  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                        16.15                       18.52
#
#    last_year_return_per_risk  last_three_years_return_per_risk  \
# 0                       0.94                               NaN
# 1                       0.62                               NaN
# 2                       2.04                              0.64
#
#    last_five_years_return_per_risk
# 0                              NaN
# 1                              NaN
# 2                             0.67

# %% [markdown]
# <a id="save"></a>
# ## Save the data

# %%
etf_df.to_csv("justetf.csv", index=False)

# %% [markdown]
# <a id="visualize"></a>
# ## Visualize some statistics

# %%
sns.histplot(etf_df, y="strategy", hue="strategy", discrete=True)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='strategy'>

# %%
sns.histplot(etf_df, y="instrument", hue="instrument", discrete=True)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='instrument'>

# %%
sns.histplot(etf_df, y="asset", hue="asset", discrete=True)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='asset'>

# %%
sns.histplot(etf_df, y="region", hue="region", discrete=True)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='region'>

# %%
sns.histplot(etf_df, y="currency", hue="currency", discrete=True)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='currency'>

# %%
sns.scatterplot(data=etf_df, x="age", y="size", alpha=0.5, linewidth=0)
# Out:
# <AxesSubplot:xlabel='age', ylabel='size'>

# %% [markdown]
# The most frequent indices.

# %%
index_counts = etf_df["index"].value_counts()

# %%
sns.histplot(
    etf_df[etf_df["index"].isin(index_counts[index_counts > 7].index)],
    y="index",
    discrete=True,
)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='index'>

# %% [markdown]
# <a id="search"></a>
# ## Search over the data

# %% [markdown]
# Compare accumulating MSCI World ETFs older than 2 years with fond size greater than € 50M.

# %%
acc_msci_world_df = etf_df[
    (etf_df["index"] == "MSCI World")
    & (etf_df["dividends"] == "Accumulating")
    & (etf_df["age"] > 2)
    & (etf_df["size"] > 50)
]

# %%
acc_msci_world_df.shape
# Out:
# (9, 46)

# %%
acc_msci_world_df
# Out:
#               isin     wkn ticker     valor  \
# 2171  FR0014003IY1  LYX9ZB   WLDC      <NA>
# 2176  LU1681043599  A2H59Q   AMEW  38784696
# 2177  LU1681043672  A2H59R   XAMZ  38784715
# 2179  LU1781541179  LYX0YD   LCUW  40587053
# 2183  IE00B60SX394  A0RGCS   SC0J  10128224
# 2184  IE00B4L5Y983  A0RPWH   EUNL  10608388
# 2187  IE00BFY0GT14  A2N6CW   SPPW  46170158
# 2191  LU0274208692  DBX1MW   DBXW   2825395
# 2193  IE00BJ0KDQ92  A1XB5U   XDWD  24869934
#
#                                              name       index       date  \
# 2171           Amundi MSCI World II UCITS ETF Acc  MSCI World 2021-06-02
# 2176          Amundi MSCI World UCITS ETF EUR (C)  MSCI World 2009-06-16
# 2177          Amundi MSCI World UCITS ETF USD (C)  MSCI World 2010-06-17
# 2179            Amundi MSCI World V UCITS ETF Acc  MSCI World 2018-02-28
# 2183             Invesco MSCI World UCITS ETF Acc  MSCI World 2009-04-02
# 2184  iShares Core MSCI World UCITS ETF USD (Acc)  MSCI World 2009-09-25
# 2187                    SPDR MSCI World UCITS ETF  MSCI World 2019-02-28
# 2191       Xtrackers MSCI World Swap UCITS ETF 1C  MSCI World 2006-12-19
# 2193            Xtrackers MSCI World UCITS ETF 1C  MSCI World 2014-07-22
#
#             age   strategy domicile_country currency  hedged  \
# 2171   2.820859  Long-only           France      EUR   False
# 2176  14.790722  Long-only       Luxembourg      EUR   False
# 2177  13.787983  Long-only       Luxembourg      USD   False
# 2179   6.081133  Long-only       Luxembourg      USD   False
# 2183  14.996202  Long-only          Ireland      USD   False
# 2184  14.514010  Long-only          Ireland      USD   False
# 2187   5.081133  Long-only          Ireland      USD   False
# 2191  17.283873  Long-only       Luxembourg      USD   False
# 2193   9.689353  Long-only          Ireland      USD   False
#
#       securities_lending     dividends   ter          replication   size  \
# 2171               False  Accumulating  0.30  Swap based Unfunded     68
# 2176               False  Accumulating  0.38  Swap based Unfunded   3303
# 2177               False  Accumulating  0.38  Swap based Unfunded     65
# 2179                True  Accumulating  0.12     Full replication   4445
# 2183               False  Accumulating  0.19  Swap based Unfunded   4353
# 2184                True  Accumulating  0.20   Optimized sampling  67045
# 2187                True  Accumulating  0.12   Optimized sampling   4968
# 2191               False  Accumulating  0.45  Swap based Unfunded   3861
# 2193                True  Accumulating  0.19   Optimized sampling  10678
#
#        asset instrument region  at_gettex  at_xetra  at_london  at_euronext  \
# 2171  Equity        ETF  World      False     False      False        False
# 2176  Equity        ETF  World       True      True      False         True
# 2177  Equity        ETF  World       True     False       True         True
# 2179  Equity        ETF  World       True      True       True         True
# 2183  Equity        ETF  World       True      True       True        False
# 2184  Equity        ETF  World       True      True       True        False
# 2187  Equity        ETF  World       True      True       True        False
# 2191  Equity        ETF  World       True      True       True        False
# 2193  Equity        ETF  World       True      True       True        False
#
#       at_stuttgart  at_six  yesterday  last_week  last_month  \
# 2171         False   False      10.38       1.66        2.58
# 2176          True    True      10.68       1.36        3.47
# 2177         False    True      10.64       1.25        3.40
# 2179          True   False      10.97       1.53        3.62
# 2183          True    True      10.78       1.33        3.50
# 2184          True    True      10.82       1.38        3.55
# 2187         False    True      11.00       1.47        3.69
# 2191          True    True      10.71       1.30        3.47
# 2193          True    True      10.84       1.41        3.57
#
#       last_three_months  last_six_months  last_year  last_three_years  \
# 2171              10.65            16.77      28.30               NaN
# 2176              10.96            18.55      28.47             38.59
# 2177              11.02            18.71      28.17             38.32
# 2179              10.97            19.10      28.80             39.06
# 2183              11.15            18.93      28.58             39.41
# 2184              11.19            18.94      28.58             39.27
# 2187              11.34            19.13      28.84             39.92
# 2191              11.06            18.79      28.31             38.61
# 2193              11.20            19.00      28.60             39.26
#
#       last_five_years   2023   2022   2021  2020  last_dividends  \
# 2171              NaN  19.77 -12.72    NaN   NaN             NaN
# 2176            83.29  19.46 -12.87  30.94  6.26             NaN
# 2177            83.34  19.35 -13.17  31.85  6.04             NaN
# 2179            84.33  19.50 -13.19  31.96  6.12             NaN
# 2183            85.77  19.66 -12.96  32.12  6.28             NaN
# 2184            85.23  19.55 -12.96  32.10  6.13             NaN
# 2187            86.04  19.60 -12.74  32.09  6.06             NaN
# 2191            84.33  19.44 -13.13  31.91  6.14             NaN
# 2193            85.15  19.61 -13.03  32.04  6.19             NaN
#
#       last_year_dividends  last_year_volatility  last_three_years_volatility  \
# 2171                  NaN                  9.75                          NaN
# 2176                  NaN                  9.77                        13.83
# 2177                  NaN                 10.43                        15.06
# 2179                  NaN                 10.38                        16.09
# 2183                  NaN                 10.40                        15.02
# 2184                  NaN                 10.43                        15.02
# 2187                  NaN                 10.41                        14.99
# 2191                  NaN                 10.41                        15.00
# 2193                  NaN                 10.42                        14.97
#
#       last_five_years_volatility  last_year_return_per_risk  \
# 2171                         NaN                       2.89
# 2176                       17.38                       2.90
# 2177                       18.15                       2.69
# 2179                       18.70                       2.77
# 2183                       18.20                       2.74
# 2184                       18.16                       2.73
# 2187                       18.14                       2.76
# 2191                       18.18                       2.71
# 2193                       18.12                       2.74
#
#       last_three_years_return_per_risk  last_five_years_return_per_risk
# 2171                               NaN                              NaN
# 2176                              0.83                             0.74
# 2177                              0.76                             0.71
# 2179                              0.72                             0.70
# 2183                              0.78                             0.72
# 2184                              0.78                             0.72
# 2187                              0.79                             0.73
# 2191                              0.77                             0.71
# 2193                              0.78                             0.72

# %%
COLUMNS_MAPPINGS = {
    "Short-term return": {
        "isin": "isin",
        "last_six_months": "Last 5 months",
        "last_three_months": "Last 3 months",
        "last_month": "Last month",
        "last_week": "Last week",
        "yesterday": "Yesterday",
    },
    "Mid-term return": {
        "isin": "isin",
        "last_five_years": "last 5 years",
        "last_three_years": "last 3 years",
        "last_year": "last year",
    },
    "Volatility": {
        "isin": "isin",
        "last_five_years_volatility": "Last 5 years",
        "last_three_years_volatility": "Last 3 years",
        "last_year_volatility": "Last year",
    },
    "Return/Risk": {
        "isin": "isin",
        "last_five_years_return_per_risk": "Last 5 years",
        "last_three_years_return_per_risk": "Last 3 years",
        "last_year_return_per_risk": "Last year",
    },
}

# %%
for title, mapping in COLUMNS_MAPPINGS.items():
    df = acc_msci_world_df[mapping.keys()].rename(columns=mapping)
    plt.figure(dpi=150)
    ax = pd.plotting.parallel_coordinates(df, "isin", colormap="tab10", alpha=0.75)
    _ = ax.set_title(title)

# %%
df = acc_msci_world_df[["isin"] + list(reversed(last_four_years))]

# %%
plt.figure(dpi=150)
ax = pd.plotting.parallel_coordinates(df, "isin", colormap="tab10", alpha=0.75)
_ = ax.set_title("Return")

# %%
df = df.set_index("isin")

# %%
ter = (100 - acc_msci_world_df.set_index("isin")["ter"]) / 100

# %%
df = ((100 + df) / 100).mul(ter, axis=0)

# %%
cum_df = df.copy()

# %%
df = (df * 100 - 100).reset_index()

# %%
cum_df[last_four_years[1]] *= cum_df[last_four_years[0]]
cum_df[last_four_years[2]] *= cum_df[last_four_years[1]]
cum_df[last_four_years[3]] *= cum_df[last_four_years[2]]

# %%
cum_df = (cum_df * 100 - 100).reset_index()

# %%
plt.figure(dpi=150)
ax = pd.plotting.parallel_coordinates(df, "isin", colormap="tab10", alpha=0.75)
_ = ax.set_title("Return excl. TER")

# %%
plt.figure(dpi=150)
ax = pd.plotting.parallel_coordinates(cum_df, "isin", colormap="tab10", alpha=0.75)
_ = ax.set_title("Cumulative return since year excl. TER")
